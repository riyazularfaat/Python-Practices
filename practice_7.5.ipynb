# %% [markdown]
# ### Common Friends

# %% [markdown]
# ##### Problem-1
# Given two sets of friends from two people, find the mutual friends, unique friends of each, and the total number of unique friends.
#
# Example Input:
#
# a_friends = {"Rahim", "Karim", "Sakib", "Jamal"}
#
# b_friends = {"Sakib", "Jamal", "Rafiq", "Nadim"}
#
# Expected Output:
#
# Mutual friends: {'Sakib', 'Jamal'}
#
# Unique to A: {'Rahim', 'Karim'}
#
# Unique to B: {'Rafiq', 'Nadim'}
#
# Total unique friends: 6

# %%
a_friend = set(map(str, input().split()))
b_friend = set(map(str, input().split()))

mutual_friends = a_friend.intersection(b_friend)
unique_to_a = a_friend.difference(b_friend)
unique_to_b = b_friend.difference(a_friend)
unique_friends = a_friend.union(b_friend)
print(f"Mutual Friends: {mutual_friends}")
print(f"Unique to A: {unique_to_a}")
print(f"Unique to B: {unique_to_b}")
print(f"Total unique friends: {len(unique_friends)}")
# Out:
#  Rohim Korim Sakib Jamal
#  Sakib Jamal Rafiq Nadim
# Mutual Friends: {'Jamal', 'Sakib'}
# Unique to A: {'Rohim', 'Korim'}
# Unique to B: {'Nadim', 'Rafiq'}
# Total unique friends: 6

# %% [markdown]
# ### Problem 2: Sort Students by Marks (Tuple + Dictionary)‎

# %% [markdown]
# Problem:
# You are given a list of tuples — each containing a student’s name and mark.
# Sort them in descending order of marks and print the top 3 scorers.‎
# Example Input:
# students = [("Rafi", 89), ("Sumi", 95), ("Hasan", 90), ("Nila", 75), ("Anik", 98)]
#
# Expected Output:
# Top 3 students:
# Anik - 98
# Sumi - 95
# Hasan - 90

# %%
import ast
students = ast.literal_eval(input())
# students_dict = {name: mark for name, mark in students}
sorted_students = sorted(students, key=lambda x: x[1], reverse=True)
top_3_scorers = sorted_students[:3]
print("Top 3 scorers:")
for name, mark in top_3_scorers:
    print(f"{name} : {mark}")
# Out:
#  [("Rafi", 89), ("Sumi", 95), ("Hasan", 90), ("Nila", 75), ("Anik", 98)]
# Top 3 scorers:
# Anik : 98
# Sumi : 95
# Hasan : 90

# %% [markdown]
# ### Problem 3: Word Length Filter (Lambda + Filter)‎

# %% [markdown]
# Problem:
# ‎ Given a list of words, use filter() and lambda to return only words whose length is greater than ‎‎4.
# ‎ Example Input:‎
# words = ["sun", "planet", "moon", "star", "universe"]‎
#
# Expected Output:‎
# ‎['planet', 'universe']‎

# %%
words = list(map(str, input().split()))
length_words = list(filter(lambda x: len(x) > 4, words))
print(length_words)
# Out:
#  sun moon planet universe
# ['planet', 'universe']

# %% [markdown]
# ### Problem 4: Square of Even Numbers (Map + Filter + Lambda)‎

# %% [markdown]
# Problem:
# Write a one-line Python expression using map(), filter(), and lambda that takes a list of integers and returns the squares of even numbers only.
# Example Input
# nums = [1, 2, 3, 4, 5, 6]
#
# Expected Output:
# [4, 16, 36]

# %%
nums = list(map(int, input().split()))
square_of_evens = list(map(lambda x: x**2, filter(lambda x: x if x % 2 == 0 else False, nums)))
print(square_of_evens)
# Out:
#  1 2 3 4 5 6 7 8 9
# [4, 16, 36, 64]

# %% [markdown]
# ### Problem 5: Write and Read a File

# %% [markdown]
# Problem:
# Write a Python program to:
#
# 1.‎	Create a text file named data.txt
#
# 2.‎	Write “Learning Python is fun!” into it.
#
# 3.‎	Read the file and print its content.‎

# %%
# 1
with open("data.txt", 'w') as file:
    # 2
    file.write("Learning Python is fun!")

# 3
with open("data.txt", 'r') as read_file:
    content = read_file.read()
    print(content)
# Out:
# Learning Python is fun!

# %% [markdown]
# ### Problem 6: Count Lines in a File
# **Problem:**
#
# ‎ Write a Python program to count how many lines are in a text file named story.txt.
#
# ‎ If the file does not exist, handle the exception and print an error message, otherwise read the text ‎file ( test it with both conditions ). Print a message finally. ‎

# %%
with open("data.txt", "a") as file:

    file.write("\nHello world!")
    file.write("\nThis is Arfaat.")

# %%
try:
    with open("data.txt", "r") as file:
        content = file.readlines()
        print(len(content))
except FileNotFoundError:
    print("File does not exist.")
# Out:
# 9
